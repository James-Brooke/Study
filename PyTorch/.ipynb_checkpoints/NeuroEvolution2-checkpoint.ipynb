# %%
from IPython.display import HTML
HTML('''<script>
code_show=false; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<b>Note:</b> the raw code for this notebook is by default hidden for easier reading.
To toggle the code on/off, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=false;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <b>Note:</b> the raw code for this notebook is by default hidden for easier reading.
# To toggle the code on/off, click <a href="javascript:code_toggle()">here</a>.

# %% [markdown]
# # Setup

# %%
import torch
import Darwin as dw
import seaborn as sns

from torchvision import datasets, transforms
from bogus import atk
from ipywidgets  import interactive, fixed
from bokeh.io import output_notebook

output_notebook()
sns.set()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="43bb1a79-e65f-4899-9ac1-867a477b8b3a">Loading BokehJS ...</span>
#     </div>

# %%
torch.backends.cudnn.benchmark=True

# %%
with open(r"D:\TELEGRAM_BOTS\NEURALUPDATES.txt") as file: #Credentials for telegram bot
    telegram_credentials = file.read().split('\n')

# %%
transform = transforms.Compose([
                       transforms.ToTensor()])

MNIST_train = datasets.MNIST(r'D:\Data_sets/MNIST', 
                            train=True, download=True,
                            transform=transform)

MNIST_test = datasets.MNIST(r'D:\Data_sets/MNIST', 
                            train=False, download=True,
                            transform=transform)

train_loader = torch.utils.data.DataLoader(
                            MNIST_train, batch_size=64, 
                            shuffle=True, pin_memory=True)

test_loader = torch.utils.data.DataLoader(MNIST_test,
                            batch_size=1000, shuffle=True, 
                            pin_memory=True)

# %%
NET_SPACE = {
    'nb_layers': {'lb': 1, 'ub': 3, 'mutate': 0.15},
    'lr': {'lb': 0.001, 'ub':0.1, 'mutate': 0.15},
    'weight_decay': {'lb': 0.00001, 'ub': 0.0004, 'mutate':0.2},
    'optimizer': {'func': ['sgd', 'adam', 'adadelta','rmsprop'], 'mutate': 0.2}
}

# %%
LAYER_SPACE = {
    'nb_units':{'lb': 128, 'ub':2048, 'mutate': 0.15},
    'dropout_rate': {'lb': 0.0, 'ub': 0.7, 'mutate': 0.2},
    'activation': {'func': ['linear','tanh','relu','sigmoid','elu'], 'mutate':0.2}
}

# %%
atk_func = atk()

# %% [markdown]
# # Run

# %%
testing = dw.TournamentOptimizer(4, LAYER_SPACE, NET_SPACE, dw.randomize_network, 
                           dw.mutate_net, dw.NetFromBuildInfo, dw.train, dw.test,
                          train_loader, test_loader, atk_func.fgsm, telegram_credentials)

# %%
testing.step(generations=1, epochs=2, save=True, phone=False)
# Out:
# HBox(children=(IntProgress(value=0, description='Overall progress', max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4), HTML(value='')))
# Generation 1 Population mean:420.5 max:980
#
# Top performers:
# 0: score:980
# 1: score:702

# %% [markdown]
# # Plots

# %%
dw.progressplotter(testing, clean=True)

# %%
dw.progressplotter(testing)

# %%
dw.diffplotter(testing)

# %%
dw.bestplotter(testing, k=0)

# %%
dw.avgplotter(testing)

# %%
dw.best_printer(testing)
# Out:
#                   adversarial  clean  generation
# best_adversarial          980    980           1
# best_clean                  0   9489           1

# %%
dw.multi_plot(testing, test_loader, adv_func=atk_func.fgsm, adversarial=True, eps=0.5)
# Out:
# Showing best model which was found in generation 1
# Clean accuracy = 980
# adversarial accuracy =980
#
# Model:
#
#  NetFromBuildInfo(
#   (model): Sequential(
#     (flatten): Flatten()
#     (fc_0): Linear(in_features=784, out_features=599, bias=True)
#     (dropout_0): Dropout(p=0.2288252078372684)
#     (elu0): ELU(alpha=1.0)
#     (fc_1): Linear(in_features=599, out_features=1880, bias=True)
#     (dropout_1): Dropout(p=0.07546691844508346)
#     (sigmoid1): Sigmoid()
#     (logits): Linear(in_features=1880, out_features=10, bias=True)
#     (log_softmax): LogSoftmax()
#   )
# )
#
#  Images below are adversarial
# [[7.8695547e-04 2.5425416e-27 1.3677312e-13 9.3461762e-13 3.7267053e-01
#   6.2652928e-01 7.9929558e-21 2.3615460e-10 4.3769035e-07 7.0064923e-45]]
# [[1.0000000e+00 1.3055215e-28 7.5231127e-20 8.4467987e-18 2.0571386e-10
#   2.7971885e-06 2.3357397e-28 1.8051668e-14 1.5237771e-15 0.0000000e+00]]
# [[6.0792249e-02 1.4151994e-31 6.2719580e-18 5.3638356e-16 1.3388552e-11
#   9.3921238e-01 1.7698064e-21 2.8423066e-09 6.3884904e-11 0.0000000e+00]]
# [[6.9225711e-01 3.4354290e-31 9.1218439e-12 2.4741648e-15 2.2614034e-02
#   2.8509185e-01 7.6726883e-21 2.4508037e-07 4.9611623e-05 1.4012985e-45]]
# [[5.0127378e-04 2.0009083e-27 7.1865718e-14 2.7574178e-13 2.4102972e-06
#   9.9948132e-01 1.2561726e-22 1.2135810e-10 1.4448576e-09 0.0000000e+00]]
# [[1.0000000e+00 2.9610513e-38 8.9867811e-23 8.9500761e-22 1.2534548e-13
#   3.0069238e-08 5.9058551e-29 7.0345797e-19 1.0819939e-12 0.0000000e+00]]
# [[9.6289462e-01 1.4484755e-27 1.7491831e-11 1.7260449e-17 1.5383510e-05
#   3.7079994e-02 5.0545834e-17 2.7380770e-07 1.0996113e-05 0.0000000e+00]]
# [[5.7877326e-01 2.6519778e-26 4.6087954e-13 1.6682331e-14 6.7316423e-06
#   4.2119703e-01 1.1725032e-16 1.6853074e-11 1.5594800e-05 0.0000000e+00]]
# [[4.2187155e-05 3.1011462e-36 1.5300829e-18 9.1470537e-16 5.7324374e-05
#   9.9990845e-01 1.4584014e-25 1.3064046e-11 4.9363416e-11 0.0000000e+00]]

# %%
dw.multi_plot(testing, test_loader, adversarial=False)
# Out:
# Showing best model which was found in generation 1
# Clean accuracy = 980
# adversarial accuracy =980
#
# Model:
#
#  NetFromBuildInfo(
#   (model): Sequential(
#     (flatten): Flatten()
#     (fc_0): Linear(in_features=784, out_features=599, bias=True)
#     (dropout_0): Dropout(p=0.2288252078372684)
#     (elu0): ELU(alpha=1.0)
#     (fc_1): Linear(in_features=599, out_features=1880, bias=True)
#     (dropout_1): Dropout(p=0.07546691844508346)
#     (sigmoid1): Sigmoid()
#     (logits): Linear(in_features=1880, out_features=10, bias=True)
#     (log_softmax): LogSoftmax()
#   )
# )
#
#  Images below are clean
# [[3.6240819e-01 2.3267430e-33 1.6718227e-18 1.8657239e-16 1.0028960e-07
#   6.3760090e-01 5.9954457e-23 3.3989237e-12 1.5075631e-10 0.0000000e+00]]
# [[7.6206615e-03 2.0961523e-25 5.7601020e-12 1.2308625e-13 9.8509753e-01
#   7.2916858e-03 5.4671206e-25 1.8234139e-10 6.2595545e-10 0.0000000e+00]]
# [[9.8422605e-01 2.7753592e-27 4.4460208e-20 2.6354404e-17 1.9494710e-05
#   1.5740957e-02 8.3347818e-23 2.7928662e-09 1.1199728e-07 0.0000000e+00]]
# [[9.9938983e-01 2.6364299e-29 1.2830527e-20 2.7749469e-19 5.5497803e-04
#   5.4116506e-05 1.0819815e-27 5.1984393e-13 1.5216658e-11 0.0000000e+00]]
# [[9.0768051e-01 1.0432023e-27 3.5651102e-14 9.3896931e-15 9.1995388e-02
#   3.1266647e-04 8.0039402e-21 1.2034101e-12 1.6241769e-14 0.0000000e+00]]
# [[9.2907912e-06 5.2655252e-33 1.4667783e-22 1.1289963e-25 7.4478876e-08
#   1.0000000e+00 7.2105831e-26 8.6423314e-17 1.1517214e-16 0.0000000e+00]]
# [[9.99938965e-01 1.56004252e-31 3.26483578e-13 4.07723015e-16
#   5.28790333e-05 1.65101972e-06 8.09933021e-23 4.13550453e-07
#   1.05248074e-10 0.00000000e+00]]
# [[1.3133968e-01 5.1606873e-33 5.2681225e-16 5.1241296e-15 8.9051653e-05
#   8.6857647e-01 5.2993126e-20 2.6695385e-10 7.7303594e-06 0.0000000e+00]]
# [[9.8593962e-01 1.2419497e-30 2.1322266e-17 6.1965359e-14 2.4815690e-05
#   1.4050375e-02 8.1754270e-27 3.6126310e-13 1.3952182e-13 0.0000000e+00]]

# %%
df = dw.dataframer(testing)
#df.to_pickle(r"../data/neuroevolution4")

# %%
opts = df.columns.tolist()[:-1] #last column contains dicts which causes bokeh to fail
gen_opts = ['all'] + df['Generation'].unique().tolist() 
y1_opts = opts[2:] + opts[:2]
y2_opts = opts[1:] + opts[:1]
interactive_plot = interactive(dw.int_plot, df=fixed(df), x=opts, y=y1_opts, x2=opts, y2=y2_opts, gen=gen_opts)

# %%
interactive_plot #bokeh does not show on Github due to JS restrictions
# Out:
# interactive(children=(Dropdown(description='x', options=('Generation', 'Clean', 'Adversarial', 'No_layers', 'L…
